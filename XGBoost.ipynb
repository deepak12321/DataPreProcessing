# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
train = pd.read_excel('ptrain.xlsx')
test = pd.read_excel('ptest.xlsx')

# %%
x_train = train.drop(['temperature_2m (°C)', 'Date'] , axis = 1)
y_train = train['temperature_2m (°C)']

x_test = test.drop(['temperature_2m (°C)' , 'Date'], axis = 1)
y_test = test['temperature_2m (°C)']

# %%
xgb_model = xgb.XGBRegressor()
xgb_model.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
train_pred = xgb_model.predict(x_train)
train_pred
# Out:
# array([10.412271 , 11.124766 , 11.276516 , ...,  8.544152 ,  9.6446495,
#        12.83508  ], dtype=float32)

# %%
mse_train = mean_squared_error(y_train, train_pred)
print(f'Mean Squared Error: {mse_train}')
# Out:
# Mean Squared Error: 0.0031750938718558145

# %%
predictions = pd.DataFrame()
predictions['actual'] = y_train
predictions['predicted'] = train_pred
predictions ['error'] = predictions['predicted'] - predictions['actual']
predictions
# Out:
#          actual  predicted     error
# 0     10.450000  10.412271 -0.037729
# 1     11.100000  11.124766  0.024766
# 2     11.279167  11.276516 -0.002651
# 3     11.262500  11.305967  0.043467
# 4     10.591667  10.584552 -0.007115
# ...         ...        ...       ...
# 6995  12.233333  12.284628  0.051295
# 6996  12.379167  12.384876  0.005710
# 6997   8.500000   8.544152  0.044152
# 6998   9.654167   9.644650 -0.009517
# 6999  12.862500  12.835080 -0.027420
#
# [7000 rows x 3 columns]

# %%
mean_absolute_error(predictions["actual"],predictions["predicted"])
# Out:
# 0.010720332976871748

# %%
xgb_model.fit(x_test, y_test)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
test_pred = xgb_model.predict(x_test)
test_pred
# Out:
# array([13.788426, 13.542661, 13.293107, ..., 14.493952, 15.414533,
#        16.75898 ], dtype=float32)

# %%
mse_test = mean_squared_error(y_test, test_pred)
print(f'Mean Squared Error: {mse_test}')
# Out:
# Mean Squared Error: 0.0002154651656265176

# %%
predictions = pd.DataFrame()
predictions['actual'] = y_test
predictions['predicted'] = test_pred
predictions ['error'] = predictions['predicted'] - predictions['actual']
predictions
# Out:
#          actual  predicted     error
# 0     13.770833  13.788426  0.017593
# 1     13.529167  13.542661  0.013494
# 2     13.283333  13.293107  0.009774
# 3     13.766667  13.756021 -0.010645
# 4     14.500000  14.487251 -0.012749
# ...         ...        ...       ...
# 1822  14.633333  14.635939  0.002605
# 1823  12.187500  12.183268 -0.004232
# 1824  14.504167  14.493952 -0.010215
# 1825  15.412500  15.414533  0.002033
# 1826  16.754167  16.758980  0.004813
#
# [1827 rows x 3 columns]

# %%
mean_absolute_error(predictions["actual"],predictions["predicted"])
# Out:
# 0.010720332976871748

# %%
print("Train predction msc :", mse_train)
print("Test prediction msc :", mse_test)
# Out:
# Train predction msc : 0.0031750938718558145
# Test prediction msc : 0.0002154651656265176
