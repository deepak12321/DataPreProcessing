# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
train = pd.read_excel('ptrain.xlsx')
test = pd.read_excel('ptest.xlsx')

# %%
x_train = train.drop(['temperature_2m (°C)', 'Date'] , axis = 1)
y_train = train['temperature_2m (°C)']

x_test = test.drop(['temperature_2m (°C)' , 'Date'], axis = 1)
y_test = test['temperature_2m (°C)']

# %%
regressor = RandomForestRegressor(n_estimators=100, max_depth=30)  # best result at max_depth :- 20  0.008125022644958076
regressor.fit(x_train, y_train)

# at 30   --> 0.00797790615575399
# Out:
# RandomForestRegressor(max_depth=30)

# %%
train_pred = regressor.predict(x_train)
train_pred
# Out:
# array([10.43683333, 11.11333333, 11.285125  , ...,  8.49429167,
#         9.62883333, 12.89725   ])

# %%
mse_train = mean_squared_error(y_train, train_pred)
print(f'Mean Squared Error: {mse_train}')
# Out:
# Mean Squared Error: 0.008026658676339305

# %%
predictions = pd.DataFrame()
predictions['actual'] = y_train
predictions['predicted'] = train_pred
predictions ['error'] = predictions['predicted'] - predictions['actual']
predictions
# Out:
#          actual  predicted     error
# 0     10.450000  10.436833 -0.013167
# 1     11.100000  11.113333  0.013333
# 2     11.279167  11.285125  0.005958
# 3     11.262500  11.300000  0.037500
# 4     10.591667  10.593417  0.001750
# ...         ...        ...       ...
# 6995  12.233333  12.180292 -0.053042
# 6996  12.379167  12.449458  0.070292
# 6997   8.500000   8.494292 -0.005708
# 6998   9.654167   9.628833 -0.025333
# 6999  12.862500  12.897250  0.034750
#
# [7000 rows x 3 columns]

# %%
mean_absolute_error(predictions["actual"],predictions["predicted"])
# Out:
# 0.05606413690476186

# %%
regressor.fit(x_test, y_test)
# Out:
# RandomForestRegressor(max_depth=30)

# %%
test_pred = regressor.predict(x_test)
test_pred
# Out:
# array([13.87995833, 13.60704167, 13.31533333, ..., 14.50825   ,
#        15.45920833, 16.71516667])

# %%
mse_test = mean_squared_error(y_test, test_pred)
print(f'Mean Squared Error: {mse_test}')
# Out:
# Mean Squared Error: 0.015708572702859806

# %%
predictions = pd.DataFrame()
predictions['actual'] = y_test
predictions['predicted'] = test_pred
predictions ['error'] = predictions['predicted'] - predictions['actual']
predictions
# Out:
#          actual  predicted     error
# 0     13.770833  13.879958  0.109125
# 1     13.529167  13.607042  0.077875
# 2     13.283333  13.315333  0.032000
# 3     13.766667  13.787917  0.021250
# 4     14.500000  14.518875  0.018875
# ...         ...        ...       ...
# 1822  14.633333  14.473333 -0.160000
# 1823  12.187500  12.170958 -0.016542
# 1824  14.504167  14.508250  0.004083
# 1825  15.412500  15.459208  0.046708
# 1826  16.754167  16.715167 -0.039000
#
# [1827 rows x 3 columns]

# %%
print("Train predction msc :", mse_train)
print("Test prediction msc :", mse_test)
# Out:
# Train predction msc : 0.008026658676339305
# Test prediction msc : 0.015708572702859806
