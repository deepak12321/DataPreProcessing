# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
train = pd.read_excel('ptrain.xlsx')
test = pd.read_excel('ptest.xlsx')

# %%
x_train = train.drop(['temperature_2m (°C)', 'Date'] , axis = 1)
y_train = train['temperature_2m (°C)']

x_test = test.drop(['temperature_2m (°C)' , 'Date'], axis = 1)
y_test = test['temperature_2m (°C)']

# %%
ridge = Ridge(alpha = 0.1)
ridge.fit(x_train , y_train )
# Out:
# Ridge(alpha=0.1)

# %%
train_pred = ridge.predict(x_train)
train_pred
# Out:
# array([10.43229073, 11.0846722 , 11.25310494, ...,  8.52930474,
#         9.68846919, 12.90967569])

# %%
mse_train = mean_squared_error(y_train, train_pred)
print(f'Mean Squared Error: {mse_train}')
# Out:
# Mean Squared Error: 0.0005067880976842752

# %%
predictions = pd.DataFrame()
predictions['actual'] = y_train
predictions['predicted'] = train_pred
predictions ['error'] = predictions['predicted'] - predictions['actual']
predictions
# Out:
#          actual  predicted     error
# 0     10.450000  10.432291 -0.017709
# 1     11.100000  11.084672 -0.015328
# 2     11.279167  11.253105 -0.026062
# 3     11.262500  11.254936 -0.007564
# 4     10.591667  10.578464 -0.013203
# ...         ...        ...       ...
# 6995  12.233333  12.280579  0.047245
# 6996  12.379167  12.408662  0.029495
# 6997   8.500000   8.529305  0.029305
# 6998   9.654167   9.688469  0.034303
# 6999  12.862500  12.909676  0.047176
#
# [7000 rows x 3 columns]

# %%
mean_absolute_error(predictions["actual"],predictions["predicted"])
# Out:
# 0.017845489399007538

# %%
ridge.fit(x_test , y_test)
# Out:
# Ridge(alpha=0.1)

# %%
test_pred = ridge.predict(x_test)
test_pred
# Out:
# array([13.76682283, 13.54691041, 13.32031208, ..., 14.53376228,
#        15.43952192, 16.76939484])

# %%
mse_test = mean_squared_error(y_test, test_pred)
print(f'Mean Squared Error: {mse_test}')
# Out:
# Mean Squared Error: 0.0005291707799874284

# %%
predictions = pd.DataFrame()
predictions['actual'] = y_test
predictions['predicted'] = test_pred
predictions ['error'] = predictions['predicted'] - predictions['actual']
predictions
# Out:
#          actual  predicted     error
# 0     13.770833  13.766823 -0.004011
# 1     13.529167  13.546910  0.017744
# 2     13.283333  13.320312  0.036979
# 3     13.766667  13.759244 -0.007422
# 4     14.500000  14.563609  0.063609
# ...         ...        ...       ...
# 1822  14.633333  14.642963  0.009630
# 1823  12.187500  12.183283 -0.004217
# 1824  14.504167  14.533762  0.029596
# 1825  15.412500  15.439522  0.027022
# 1826  16.754167  16.769395  0.015228
#
# [1827 rows x 3 columns]

# %%
mean_absolute_error(predictions["actual"],predictions["predicted"])
# Out:
# 0.018236580878220388

# %%
print("Train predction msc :", mse_train)
print("Test prediction msc :", mse_test)
# Out:
# Train predction msc : 0.0005067880976842752
# Test prediction msc : 0.0005291707799874284
