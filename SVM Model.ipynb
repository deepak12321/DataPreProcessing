# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
train = pd.read_excel('ptrain.xlsx')
test = pd.read_excel('ptest.xlsx')

# %%
x_train = train.drop(['temperature_2m (°C)', 'Date'] , axis = 1)
y_train = train['temperature_2m (°C)']

x_test = test.drop(['temperature_2m (°C)' , 'Date'], axis = 1)
y_test = test['temperature_2m (°C)']

# %%
svm = SVR(kernel='linear', C=1.0)
svm.fit(x_train, y_train)
# Out:
# SVR(kernel='linear')

# %%
train_pred = svm.predict(x_train)
train_pred
# Out:
# array([ 9.78230798, 10.51026278, 10.85132108, ...,  8.9937763 ,
#         9.65956275, 12.61044151])

# %%
mse_train = mean_squared_error(y_train, train_pred)
print(f'Mean Squared Error: {mse_train}')
# Out:
# Mean Squared Error: 0.14379960580238918

# %%
predictions = pd.DataFrame()
predictions['actual'] = y_train
predictions['predicted'] = train_pred
predictions ['error'] = predictions['predicted'] - predictions['actual']
predictions
# Out:
#          actual  predicted     error
# 0     10.450000   9.782308 -0.667692
# 1     11.100000  10.510263 -0.589737
# 2     11.279167  10.851321 -0.427846
# 3     11.262500  10.663170 -0.599330
# 4     10.591667  10.232691 -0.358975
# ...         ...        ...       ...
# 6995  12.233333  12.176236 -0.057097
# 6996  12.379167  12.662652  0.283485
# 6997   8.500000   8.993776  0.493776
# 6998   9.654167   9.659563  0.005396
# 6999  12.862500  12.610442 -0.252058
#
# [7000 rows x 3 columns]

# %%
svm.fit(x_test, y_test)
# Out:
# SVR(kernel='linear')

# %%
test_pred = svm.predict(x_test)
test_pred
# Out:
# array([13.67193762, 13.23819375, 12.83505858, ..., 14.42733425,
#        15.40054134, 16.97234489])

# %%
mse_test = mean_squared_error(y_test, test_pred)
print(f'Mean Squared Error: {mse_test}')
# Out:
# Mean Squared Error: 0.06510695069893949

# %%
predictions = pd.DataFrame()
predictions['actual'] = y_test
predictions['predicted'] = test_pred
predictions ['error'] = predictions['predicted'] - predictions['actual']
predictions
# Out:
#          actual  predicted     error
# 0     13.770833  13.671938 -0.098896
# 1     13.529167  13.238194 -0.290973
# 2     13.283333  12.835059 -0.448275
# 3     13.766667  13.213600 -0.553067
# 4     14.500000  14.084207 -0.415793
# ...         ...        ...       ...
# 1822  14.633333  14.884127  0.250793
# 1823  12.187500  12.278463  0.090963
# 1824  14.504167  14.427334 -0.076832
# 1825  15.412500  15.400541 -0.011959
# 1826  16.754167  16.972345  0.218178
#
# [1827 rows x 3 columns]

# %%
mean_absolute_error(predictions["actual"],predictions["predicted"])
# Out:
# 0.20357816986161836

# %%
print("Train predction msc :", mse_train)
print("Test prediction msc :", mse_test)
# Out:
# Train predction msc : 0.14379960580238918
# Test prediction msc : 0.06510695069893949
